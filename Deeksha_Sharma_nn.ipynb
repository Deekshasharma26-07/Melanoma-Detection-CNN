# %% [markdown]
# Problem statement: Melanoma, a type of skin cancer, is responsible for 75% of skin cancer deaths and can be fatal if not detected early. Dermatologists often rely on manual inspection of skin lesions, which can be time-consuming and prone to human error. To address this issue, the aim of this project is to develop a deep learning model based on convolutional neural networks (CNN) that can accurately detect melanoma from skin lesion images. The model will be trained on a large dataset of annotated skin lesion images and evaluated using performance metrics such as sensitivity, specificity, and accuracy. The final solution will be an automated system that can evaluate skin lesion images and alert dermatologists about the presence of melanoma, potentially reducing the manual effort needed for diagnosis and improving early detection rates.

# %% [markdown]
# # Importing the input data from ISIC on skin cancer
# ## To do: Execute necessary actions to read the data
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Defining the path for train and test images
data_inp_train = pathlib.Path('/content/drive/MyDrive/CNN_Assignment/Train')
data_inp_test = pathlib.Path('/content/drive/MyDrive/CNN_Assignment/Test')

# %% [markdown]
# # Beginning Keras Processing

# %% [markdown]
# ## Loading images off disk using image_dataset_from_directory utility.

# %%
# Defining the path for train and test images
data_inp_train = pathlib.Path('/content/drive/MyDrive/CNN_Assignment/Train')
data_inp_test = pathlib.Path('/content/drive/MyDrive/CNN_Assignment/Test')

# %% [markdown]
# # Count in dataset

# %%
image_count_train = len(list(data_inp_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_inp_test.glob('*/*.jpg')))
print(image_count_test)

# %% [markdown]
# ## Define parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ### Allocating 80% images for training and 20%  for testing

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_inp_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    label_mode='categorical',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2249 files belonging to 9 classes.
# Using 1800 files for training.

# %%
# Test dataset
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_inp_test,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    label_mode='categorical',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
# Visualize the data
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_inp_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %%
# using autotune for better transfer learning
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# CNN model building
model=Sequential()

#rescalling 
model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 30% Fraction of the input units to drop.
model.add(layers.Dropout(0.30))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))


# model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 20, 20, 128)       0
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimiser and loss function
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
# lets run it for 20 epochs 
epochs = 20
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 24s 81ms/step - loss: 2.0984 - accuracy: 0.2244 - val_loss: 2.3275 - val_accuracy: 0.1739
# Epoch 2/20
# 57/57 [==============================] - 3s 51ms/step - loss: 1.9113 - accuracy: 0.3144 - val_loss: 2.5941 - val_accuracy: 0.1304
# Epoch 3/20
# 57/57 [==============================] - 3s 51ms/step - loss: 1.7267 - accuracy: 0.3839 - val_loss: 2.3812 - val_accuracy: 0.1304
# Epoch 4/20
# 57/57 [==============================] - 3s 51ms/step - loss: 1.5629 - accuracy: 0.4517 - val_loss: 2.5168 - val_accuracy: 0.2609
# Epoch 5/20
# 57/57 [==============================] - 3s 50ms/step - loss: 1.4706 - accuracy: 0.4800 - val_loss: 2.0810 - val_accuracy: 0.2609
# Epoch 6/20
# 57/57 [==============================] - 3s 48ms/step - loss: 1.4666 - accuracy: 0.4972 - val_loss: 2.4555 - val_accuracy: 0.3043
# Epoch 7/20
# 57/57 [==============================] - 3s 48ms/step - loss: 1.3646 - accuracy: 0.5200 - val_loss: 2.5750 - val_accuracy: 0.2174
# Epoch 8/20
# 57/57 [==============================] - 3s 49ms/step - loss: 1.3217 - accuracy: 0.5400 - val_loss: 2.5811 - val_accuracy: 0.3043
# Epoch 9/20
# 57/57 [==============================] - 3s 52ms/step - loss: 1.2436 - accuracy: 0.5572 - val_loss: 2.8259 - val_accuracy: 0.2609
# Epoch 10/20
# 57/57 [==============================] - 3s 48ms/step - loss: 1.2487 - accuracy: 0.5694 - val_loss: 2.4017 - val_accuracy: 0.3043
# Epoch 11/20
# 57/57 [==============================] - 3s 48ms/step - loss: 1.1677 - accuracy: 0.5844 - val_loss: 2.9270 - val_accuracy: 0.2174
# Epoch 12/20
# 57/57 [==============================] - 3s 49ms/step - loss: 1.1387 - accuracy: 0.5906 - val_loss: 2.8662 - val_accuracy: 0.1739
# Epoch 13/20
# 57/57 [==============================] - 3s 48ms/step - loss: 1.0962 - accuracy: 0.6056 - val_loss: 3.8066 - val_accuracy: 0.2609
# Epoch 14/20
# 57/57 [==============================] - 3s 47ms/step - loss: 1.0295 - accuracy: 0.6328 - val_loss: 3.5748 - val_accuracy: 0.1739
# Epoch 15/20
# 57/57 [==============================] - 3s 47ms/step - loss: 1.0049 - accuracy: 0.6383 - val_loss: 3.6119 - val_accuracy: 0.2609
# Epoch 16/20
# 57/57 [==============================] - 3s 50ms/step - loss: 0.9437 - accuracy: 0.6556 - val_loss: 3.3660 - val_accuracy: 0.1739
# Epoch 17/20
# 57/57 [==============================] - 3s 47ms/step - loss: 0.9278 - accuracy: 0.6572 - val_loss: 4.0297 - val_accuracy: 0.2609
# Epoch 18/20
# 57/57 [==============================] - 3s 49ms/step - loss: 0.9032 - accuracy: 0.6761 - val_loss: 3.9216 - val_accuracy: 0.1739
# Epoch 19/20
# 57/57 [==============================] - 3s 48ms/step - loss: 0.8347 - accuracy: 0.6994 - val_loss: 5.4303 - val_accuracy: 0.2174
# Epoch 20/20
# 57/57 [==============================] - 3s 49ms/step - loss: 0.8580 - accuracy: 0.6889 - val_loss: 3.6032 - val_accuracy: 0.2174

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# * The model is overfitting because we can also see difference in loss functions in training & test around the 10-11th epoch
#
# * The accuracy is just around 75-80% because there are enough features to remember the pattern.
#
# * But again, it's too early to comment on the overfitting & underfitting debate.

# %% [markdown]
# **Lets use some data augmentation strategy**

# %%
# data augmentation
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# CNN model building
model=Sequential([data_augument,layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180,180 ,3))])

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 30% Fraction of the input units to drop.
model.add(layers.Dropout(0.30))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))


# model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_1 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# optimiser and loss function
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
# training the model
epochs = 20
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs)

# %%
# lets plot our results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **We can see the performance has increased a bit and overfitting is less than the previous model**
#
# **We can do one more thing we can see class distribution to understand the data better**

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_inp_train)
df
# Out:
#                         Class  No. of Image
# 0           actinic keratosis           114
# 1        basal cell carcinoma           376
# 2             vascular lesion           139
# 3  pigmented benign keratosis           463
# 4                    melanoma           438
# 5                       nevus           366
# 6     squamous cell carcinoma           181
# 7              dermatofibroma            95
# 8        seborrheic keratosis            77

# %% [markdown]
# **From the count in above display, we can confirm the data has class imbalance and that needs to be treated**
#
# **We can try to solve by using augmentor library**

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")
# Out:
# <Axes: xlabel='No. of Image', ylabel='Class'>

# %% [markdown]
# # Handling Class Imbalance by Augmentation

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)

# %%
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/drive/MyDrive/CNN_Assignment/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F95A24A6050>: 100%|██████████| 500/500 [01:06<00:00,  7.53 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F95B12677C0>: 100%|██████████| 500/500 [00:51<00:00,  9.79 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=3872x2592 at 0x7F9659F76770>: 100%|██████████| 500/500 [00:56<00:00,  8.88 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F95A32A1060>: 100%|██████████| 500/500 [00:53<00:00,  9.27 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7F95B16D2FB0>: 100%|██████████| 500/500 [00:53<00:00,  9.36 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7F95B14404C0>: 100%|██████████| 500/500 [00:51<00:00,  9.69 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F96323EA4D0>: 100%|██████████| 500/500 [00:44<00:00, 11.15 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F96323BF1C0>: 100%|██████████| 500/500 [00:49<00:00, 10.12 Samples/s]
# Initialised with 2249 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_Assignment/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F95A22F1270>: 100%|██████████| 500/500 [00:53<00:00,  9.39 Samples/s]

# %%
# Saving augmented result in output_dir
output_dir = pathlib.Path('/content/drive/MyDrive/CNN_Assignment/Train/output')

# %%
# Count number of images we have generated
image_count_train = len(list(output_dir.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
# Creating train dataset with the augmented data
train_ds_new = tf.keras.preprocessing.image_dataset_from_directory(
  output_dir,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %%
# Creating test dataset with the augmented data
val_ds_new = tf.keras.preprocessing.image_dataset_from_directory(
  output_dir,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %%
# Exexuting autotune for optimizing the input pipeline in our ML model
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#Building new CNN Model with Augmented data

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_4 (Flatten)         (None, 51200)             0
#
#  dense_8 (Dense)             (None, 128)               6553728
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Optimiser and Loss function
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"]

# %%
epochs = 30
history = model.fit(train_ds_new,validation_data=val_ds_new,epochs=epochs)
# Out:
# Epoch 1/30
# 113/113 [==============================] - 22s 166ms/step - loss: 1.9594 - accuracy: 0.2739 - val_loss: 1.9454 - val_accuracy: 0.2489
# Epoch 2/30
# 113/113 [==============================] - 21s 175ms/step - loss: 1.6265 - accuracy: 0.4225 - val_loss: 1.4941 - val_accuracy: 0.4822
# Epoch 3/30
# 113/113 [==============================] - 20s 173ms/step - loss: 1.4620 - accuracy: 0.4853 - val_loss: 1.3843 - val_accuracy: 0.5233
# Epoch 4/30
# 113/113 [==============================] - 19s 160ms/step - loss: 1.3656 - accuracy: 0.5181 - val_loss: 1.4035 - val_accuracy: 0.4789
# Epoch 5/30
# 113/113 [==============================] - 21s 177ms/step - loss: 1.2593 - accuracy: 0.5533 - val_loss: 1.3676 - val_accuracy: 0.5111
# Epoch 6/30
# 113/113 [==============================] - 19s 163ms/step - loss: 1.1726 - accuracy: 0.5833 - val_loss: 1.1055 - val_accuracy: 0.6133
# Epoch 7/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.0815 - accuracy: 0.6144 - val_loss: 1.1139 - val_accuracy: 0.6100
# Epoch 8/30
# 113/113 [==============================] - 21s 179ms/step - loss: 1.0209 - accuracy: 0.6394 - val_loss: 1.0033 - val_accuracy: 0.6678
# Epoch 9/30
# 113/113 [==============================] - 21s 176ms/step - loss: 0.9317 - accuracy: 0.6608 - val_loss: 0.9536 - val_accuracy: 0.6900
# Epoch 10/30
# 113/113 [==============================] - 19s 164ms/step - loss: 0.8237 - accuracy: 0.7003 - val_loss: 1.0777 - val_accuracy: 0.6400
# Epoch 11/30
# 113/113 [==============================] - 19s 165ms/step - loss: 0.7934 - accuracy: 0.7117 - val_loss: 1.0358 - val_accuracy: 0.6589
# Epoch 12/30
# 113/113 [==============================] - 19s 160ms/step - loss: 0.7249 - accuracy: 0.7453 - val_loss: 0.9963 - val_accuracy: 0.6767
# Epoch 13/30
# 113/113 [==============================] - 19s 160ms/step - loss: 0.6847 - accuracy: 0.7589 - val_loss: 0.9083 - val_accuracy: 0.6989
# Epoch 14/30
# 113/113 [==============================] - 20s 169ms/step - loss: 0.6054 - accuracy: 0.7750 - val_loss: 0.9273 - val_accuracy: 0.7233
# Epoch 15/30
# 113/113 [==============================] - 19s 160ms/step - loss: 0.5463 - accuracy: 0.8000 - val_loss: 1.1027 - val_accuracy: 0.7000
# Epoch 16/30
#  39/113 [=========>....................] - ETA: 12s - loss: 0.5834 - accuracy: 0.7724

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **After treating the data for class impabalance we can predict better now due to which our model accuracy has increased to 89%**
#
# **Also the valdation loss has further decreased**

# %% [markdown]
# ### Due to slight overfitting in model parameters, adding L2 regularizer and Dropout of 20% after every layer.

# %%
from keras.regularizers import l2

#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model_3 = Sequential()

model_3.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model_3.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model_3.add(layers.MaxPool2D(pool_size=(2,2)))
model_3.add(layers.Dropout(0.2))

#Second Convulation Layer
model_3.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model_3.add(layers.MaxPool2D(pool_size=(2,2)))
model_3.add(layers.Dropout(0.2))

#Third Convulation Layer
model_3.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model_3.add(layers.MaxPool2D(pool_size=(2,2)))
model_3.add(layers.Dropout(0.2))

model_3.add(layers.Conv2D(256,kernel_size=(3,3),activation='relu'))
model_3.add(layers.MaxPool2D(pool_size=(2,2)))


#Dropout layer with 20% Fraction of the input units to drop.
model_3.add(layers.Dropout(0.2))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model_3.add(layers.Flatten())

#Dense Layer
model_3.add(layers.Dense(256,activation='relu',kernel_regularizer=l2(0.001)))

#Dropout layer with 25% Fraction of the input units to drop.
model_3.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model_3.add(layers.Dense(len(class_names),activation='softmax'))

model_3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_6 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_18 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_18 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 89, 89, 32)        0
#
#  conv2d_19 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_19 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 43, 43, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_20 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 20, 20, 128)       0
#
#  conv2d_21 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_21 (MaxPoolin  (None, 9, 9, 256)        0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 9, 9, 256)         0
#
#  flatten_6 (Flatten)         (None, 20736)             0
#
#  dense_12 (Dense)            (None, 256)               5308672
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 9)                 2313
#
# =================================================================
# Total params: 5,699,401
# Trainable params: 5,699,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
#optimiser and loss function
model_3.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
epochs = 30
history = model_3.fit(train_ds_new,validation_data=val_ds_new,epochs=epochs)
# Out:
# Epoch 1/30
# 113/113 [==============================] - 23s 171ms/step - loss: 2.2613 - accuracy: 0.2411 - val_loss: 1.9612 - val_accuracy: 0.3744
# Epoch 2/30
# 113/113 [==============================] - 22s 186ms/step - loss: 1.7846 - accuracy: 0.3861 - val_loss: 1.6569 - val_accuracy: 0.4556
# Epoch 3/30
# 113/113 [==============================] - 22s 185ms/step - loss: 1.6238 - accuracy: 0.4481 - val_loss: 1.5500 - val_accuracy: 0.4878
# Epoch 4/30
# 113/113 [==============================] - 20s 171ms/step - loss: 1.5529 - accuracy: 0.4781 - val_loss: 1.4787 - val_accuracy: 0.5111
# Epoch 5/30
# 113/113 [==============================] - 22s 185ms/step - loss: 1.4368 - accuracy: 0.5122 - val_loss: 1.3719 - val_accuracy: 0.5589
# Epoch 6/30
# 113/113 [==============================] - 20s 171ms/step - loss: 1.4098 - accuracy: 0.5194 - val_loss: 1.3769 - val_accuracy: 0.5511
# Epoch 7/30
# 113/113 [==============================] - 22s 183ms/step - loss: 1.3706 - accuracy: 0.5308 - val_loss: 1.3392 - val_accuracy: 0.5933
# Epoch 8/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.3427 - accuracy: 0.5458 - val_loss: 1.2996 - val_accuracy: 0.5844
# Epoch 9/30
# 113/113 [==============================] - 22s 184ms/step - loss: 1.3460 - accuracy: 0.5503 - val_loss: 1.2679 - val_accuracy: 0.5878
# Epoch 10/30
# 113/113 [==============================] - 22s 183ms/step - loss: 1.2632 - accuracy: 0.5836 - val_loss: 1.2588 - val_accuracy: 0.5989
# Epoch 11/30
# 113/113 [==============================] - 20s 170ms/step - loss: 1.2333 - accuracy: 0.5889 - val_loss: 1.2441 - val_accuracy: 0.6133
# Epoch 12/30
# 113/113 [==============================] - 21s 183ms/step - loss: 1.2268 - accuracy: 0.5992 - val_loss: 1.2716 - val_accuracy: 0.6056
# Epoch 13/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.1980 - accuracy: 0.6136 - val_loss: 1.1982 - val_accuracy: 0.6333
# Epoch 14/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.1698 - accuracy: 0.6256 - val_loss: 1.2969 - val_accuracy: 0.6178
# Epoch 15/30
# 113/113 [==============================] - 20s 170ms/step - loss: 1.1125 - accuracy: 0.6533 - val_loss: 1.2359 - val_accuracy: 0.6089
# Epoch 16/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.0786 - accuracy: 0.6678 - val_loss: 1.1499 - val_accuracy: 0.6811
# Epoch 17/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.0774 - accuracy: 0.6775 - val_loss: 1.2520 - val_accuracy: 0.6378
# Epoch 18/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.0258 - accuracy: 0.7036 - val_loss: 1.0949 - val_accuracy: 0.7033
# Epoch 19/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.0051 - accuracy: 0.7208 - val_loss: 1.0921 - val_accuracy: 0.7144
# Epoch 20/30
# 113/113 [==============================] - 20s 169ms/step - loss: 0.9945 - accuracy: 0.7228 - val_loss: 1.0892 - val_accuracy: 0.7278
# Epoch 21/30
# 113/113 [==============================] - 21s 179ms/step - loss: 0.9056 - accuracy: 0.7597 - val_loss: 1.0574 - val_accuracy: 0.7278
# Epoch 22/30
# 113/113 [==============================] - 20s 169ms/step - loss: 0.9086 - accuracy: 0.7619 - val_loss: 1.1168 - val_accuracy: 0.7289
# Epoch 23/30
# 113/113 [==============================] - 21s 183ms/step - loss: 0.8838 - accuracy: 0.7714 - val_loss: 1.1316 - val_accuracy: 0.7333
# Epoch 24/30
# 113/113 [==============================] - 20s 167ms/step - loss: 0.8479 - accuracy: 0.7872 - val_loss: 1.0664 - val_accuracy: 0.7522
# Epoch 25/30
# 113/113 [==============================] - 22s 184ms/step - loss: 0.8265 - accuracy: 0.7953 - val_loss: 1.0259 - val_accuracy: 0.7644
# Epoch 26/30
# 113/113 [==============================] - 20s 170ms/step - loss: 0.8172 - accuracy: 0.8033 - val_loss: 1.0006 - val_accuracy: 0.7922
# Epoch 27/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.7512 - accuracy: 0.8347 - val_loss: 0.9499 - val_accuracy: 0.7911
# Epoch 28/30
# 113/113 [==============================] - 20s 169ms/step - loss: 0.7607 - accuracy: 0.8289 - val_loss: 1.0071 - val_accuracy: 0.7867
# Epoch 29/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.7340 - accuracy: 0.8369 - val_loss: 0.9906 - val_accuracy: 0.7933
# Epoch 30/30
# 113/113 [==============================] - 20s 168ms/step - loss: 0.7439 - accuracy: 0.8378 - val_loss: 1.0080 - val_accuracy: 0.7844

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#### Accuracy has increased and also the validation loss has reduced. So the changes made are good.

# %% [markdown]
# ### Lets see what happens if we increase the dropout layer in our model

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model_4 = Sequential()

model_4.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model_4.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Dropout(0.18))

#Second Convulation Layer
model_4.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Dropout(0.18))

#Third Convulation Layer
model_4.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Dropout(0.18))

model_4.add(layers.Conv2D(256,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))


#Dropout layer with 20% Fraction of the input units to drop.
model_4.add(layers.Dropout(0.18))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model_4.add(layers.Flatten())

#Dense Layer
model_4.add(layers.Dense(256,activation='relu',kernel_regularizer=l2(0.001)))

#Dropout layer with 22% Fraction of the input units to drop.
model_4.add(layers.Dropout(0.22))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model_4.add(layers.Dense(len(class_names),activation='softmax'))

model_4.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_7 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_22 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_22 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 89, 89, 32)        0
#
#  conv2d_23 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_23 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 43, 43, 64)        0
#
#  conv2d_24 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_24 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_19 (Dropout)        (None, 20, 20, 128)       0
#
#  conv2d_25 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_25 (MaxPoolin  (None, 9, 9, 256)        0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 9, 9, 256)         0
#
#  flatten_7 (Flatten)         (None, 20736)             0
#
#  dense_14 (Dense)            (None, 256)               5308672
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_15 (Dense)            (None, 9)                 2313
#
# =================================================================
# Total params: 5,699,401
# Trainable params: 5,699,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
#optimiser and loss function
model_4.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
epochs = 30
history = model_4.fit(train_ds_new,validation_data=val_ds_new,epochs=epochs)
# Out:
# Epoch 1/30
# 113/113 [==============================] - 22s 172ms/step - loss: 2.2991 - accuracy: 0.2242 - val_loss: 1.9705 - val_accuracy: 0.3500
# Epoch 2/30
# 113/113 [==============================] - 21s 179ms/step - loss: 1.8821 - accuracy: 0.3344 - val_loss: 1.8739 - val_accuracy: 0.3289
# Epoch 3/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.6574 - accuracy: 0.4264 - val_loss: 1.5691 - val_accuracy: 0.4767
# Epoch 4/30
# 113/113 [==============================] - 21s 181ms/step - loss: 1.5503 - accuracy: 0.4689 - val_loss: 1.5415 - val_accuracy: 0.4811
# Epoch 5/30
# 113/113 [==============================] - 21s 178ms/step - loss: 1.4841 - accuracy: 0.4931 - val_loss: 1.4087 - val_accuracy: 0.5567
# Epoch 6/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.4075 - accuracy: 0.5161 - val_loss: 1.3888 - val_accuracy: 0.5389
# Epoch 7/30
# 113/113 [==============================] - 21s 181ms/step - loss: 1.3811 - accuracy: 0.5378 - val_loss: 1.3256 - val_accuracy: 0.5789
# Epoch 8/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.3401 - accuracy: 0.5547 - val_loss: 1.3400 - val_accuracy: 0.5811
# Epoch 9/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.3010 - accuracy: 0.5692 - val_loss: 1.3220 - val_accuracy: 0.5956
# Epoch 10/30
# 113/113 [==============================] - 20s 168ms/step - loss: 1.2769 - accuracy: 0.5828 - val_loss: 1.2679 - val_accuracy: 0.6022
# Epoch 11/30
# 113/113 [==============================] - 21s 181ms/step - loss: 1.2414 - accuracy: 0.6111 - val_loss: 1.3057 - val_accuracy: 0.6033
# Epoch 12/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.1695 - accuracy: 0.6322 - val_loss: 1.2907 - val_accuracy: 0.6244
# Epoch 13/30
# 113/113 [==============================] - 21s 179ms/step - loss: 1.1505 - accuracy: 0.6417 - val_loss: 1.4464 - val_accuracy: 0.5800
# Epoch 14/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.1079 - accuracy: 0.6692 - val_loss: 1.2716 - val_accuracy: 0.6178
# Epoch 15/30
# 113/113 [==============================] - 21s 181ms/step - loss: 1.0977 - accuracy: 0.6736 - val_loss: 1.0805 - val_accuracy: 0.7011
# Epoch 16/30
# 113/113 [==============================] - 20s 167ms/step - loss: 1.0016 - accuracy: 0.7122 - val_loss: 1.1385 - val_accuracy: 0.6700
# Epoch 17/30
# 113/113 [==============================] - 21s 179ms/step - loss: 1.0040 - accuracy: 0.7131 - val_loss: 1.2957 - val_accuracy: 0.6244
# Epoch 18/30
# 113/113 [==============================] - 20s 167ms/step - loss: 0.9499 - accuracy: 0.7553 - val_loss: 1.0904 - val_accuracy: 0.7267
# Epoch 19/30
# 113/113 [==============================] - 21s 183ms/step - loss: 0.9346 - accuracy: 0.7539 - val_loss: 1.0443 - val_accuracy: 0.7322
# Epoch 20/30
# 113/113 [==============================] - 22s 184ms/step - loss: 0.8872 - accuracy: 0.7792 - val_loss: 1.0432 - val_accuracy: 0.7689
# Epoch 21/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.8423 - accuracy: 0.7903 - val_loss: 1.0436 - val_accuracy: 0.7600
# Epoch 22/30
# 113/113 [==============================] - 21s 180ms/step - loss: 0.8710 - accuracy: 0.7919 - val_loss: 1.0868 - val_accuracy: 0.7611
# Epoch 23/30
# 113/113 [==============================] - 20s 166ms/step - loss: 0.8349 - accuracy: 0.8069 - val_loss: 1.0737 - val_accuracy: 0.7744
# Epoch 24/30
# 113/113 [==============================] - 21s 180ms/step - loss: 0.8148 - accuracy: 0.8131 - val_loss: 0.9658 - val_accuracy: 0.8067
# Epoch 25/30
# 113/113 [==============================] - 20s 167ms/step - loss: 0.7716 - accuracy: 0.8408 - val_loss: 1.0419 - val_accuracy: 0.7767
# Epoch 26/30
# 113/113 [==============================] - 21s 183ms/step - loss: 0.7558 - accuracy: 0.8381 - val_loss: 1.0495 - val_accuracy: 0.7611
# Epoch 27/30
# 113/113 [==============================] - 20s 168ms/step - loss: 0.6988 - accuracy: 0.8603 - val_loss: 0.9996 - val_accuracy: 0.8044
# Epoch 28/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.6776 - accuracy: 0.8617 - val_loss: 1.0823 - val_accuracy: 0.7789
# Epoch 29/30
# 113/113 [==============================] - 20s 167ms/step - loss: 0.7246 - accuracy: 0.8514 - val_loss: 1.0367 - val_accuracy: 0.8267
# Epoch 30/30
# 113/113 [==============================] - 21s 182ms/step - loss: 0.6755 - accuracy: 0.8681 - val_loss: 0.9762 - val_accuracy: 0.8222

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Add one more convolutional layer to check if our model parameter inproves.

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model_5 = Sequential()

model_5.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model_5.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model_5.add(layers.MaxPool2D(pool_size=(2,2)))
model_5.add(layers.Dropout(0.15))

#Second Convulation Layer
model_5.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model_5.add(layers.MaxPool2D(pool_size=(2,2)))
model_5.add(layers.Dropout(0.15))

#Third Convulation Layer
model_5.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model_5.add(layers.MaxPool2D(pool_size=(2,2)))
model_5.add(layers.Dropout(0.15))

# Fourth Convulation Layer
model_5.add(layers.Conv2D(256,kernel_size=(3,3),activation='relu'))
model_5.add(layers.MaxPool2D(pool_size=(2,2)))
model_5.add(layers.Dropout(0.15))

# Fifth Convulation Layer
model_5.add(layers.Conv2D(512,kernel_size=(3,3),activation='relu'))
model_5.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 15% Fraction of the input units to drop.
model_5.add(layers.Dropout(0.15))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model_5.add(layers.Flatten())

#Dense Layer
model_5.add(layers.Dense(1024,activation='relu'))

#Dropout layer with 20% Fraction of the input units to drop.
model_5.add(layers.Dropout(0.2))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model_5.add(layers.Dense(len(class_names),activation='softmax'))

model_5.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ae400debe89a> in <cell line: 4>()
#       2
#       3 #Sequential allows you to create models layer-by-layer
# ----> 4 model_5 = Sequential()
#       5
#       6 model_5.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer
#
# NameError: name 'Sequential' is not defined

# %%
#optimiser and loss function
model_5.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-feff9b2932c5> in <cell line: 2>()
#       1 #optimiser and loss function
# ----> 2 model_5.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])
#
# NameError: name 'model_5' is not defined

# %%
epochs = 30
history = model_5.fit(train_ds_new,validation_data=val_ds_new,epochs=epochs)
# Out:
# Epoch 1/30
# 113/113 [==============================] - 25s 174ms/step - loss: 2.0273 - accuracy: 0.2333 - val_loss: 1.9573 - val_accuracy: 0.2889
# Epoch 2/30
# 113/113 [==============================] - 22s 185ms/step - loss: 1.7435 - accuracy: 0.3475 - val_loss: 1.6822 - val_accuracy: 0.4044
# Epoch 3/30
# 113/113 [==============================] - 20s 170ms/step - loss: 1.5847 - accuracy: 0.4175 - val_loss: 1.4720 - val_accuracy: 0.4656
# Epoch 4/30
# 113/113 [==============================] - 22s 187ms/step - loss: 1.4756 - accuracy: 0.4789 - val_loss: 1.3856 - val_accuracy: 0.5289
# Epoch 5/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.4230 - accuracy: 0.4983 - val_loss: 1.3661 - val_accuracy: 0.5467
# Epoch 6/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.3387 - accuracy: 0.5206 - val_loss: 1.3328 - val_accuracy: 0.5422
# Epoch 7/30
# 113/113 [==============================] - 20s 169ms/step - loss: 1.2807 - accuracy: 0.5372 - val_loss: 1.3087 - val_accuracy: 0.5367
# Epoch 8/30
# 113/113 [==============================] - 22s 183ms/step - loss: 1.2519 - accuracy: 0.5533 - val_loss: 1.2332 - val_accuracy: 0.5478
# Epoch 9/30
# 113/113 [==============================] - 20s 170ms/step - loss: 1.1814 - accuracy: 0.5722 - val_loss: 1.1636 - val_accuracy: 0.5811
# Epoch 10/30
# 113/113 [==============================] - 21s 182ms/step - loss: 1.1283 - accuracy: 0.5897 - val_loss: 1.1035 - val_accuracy: 0.6278
# Epoch 11/30
# 113/113 [==============================] - 22s 186ms/step - loss: 1.0828 - accuracy: 0.5981 - val_loss: 1.2724 - val_accuracy: 0.5444
# Epoch 12/30
# 113/113 [==============================] - 22s 184ms/step - loss: 1.0527 - accuracy: 0.6078 - val_loss: 1.0624 - val_accuracy: 0.6433
# Epoch 13/30
# 113/113 [==============================] - 20s 170ms/step - loss: 0.9958 - accuracy: 0.6483 - val_loss: 1.0931 - val_accuracy: 0.6156
# Epoch 14/30
# 113/113 [==============================] - 22s 183ms/step - loss: 0.9444 - accuracy: 0.6569 - val_loss: 0.9827 - val_accuracy: 0.6589
# Epoch 15/30
# 113/113 [==============================] - 20s 170ms/step - loss: 0.8178 - accuracy: 0.7036 - val_loss: 0.9680 - val_accuracy: 0.6689
# Epoch 16/30
# 113/113 [==============================] - 22s 184ms/step - loss: 0.8246 - accuracy: 0.7008 - val_loss: 0.9392 - val_accuracy: 0.6844
# Epoch 17/30
# 113/113 [==============================] - 20s 169ms/step - loss: 0.7248 - accuracy: 0.7319 - val_loss: 0.8409 - val_accuracy: 0.7156
# Epoch 18/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.6267 - accuracy: 0.7708 - val_loss: 1.0010 - val_accuracy: 0.6778
# Epoch 19/30
# 113/113 [==============================] - 20s 171ms/step - loss: 0.6454 - accuracy: 0.7636 - val_loss: 0.9887 - val_accuracy: 0.6656
# Epoch 20/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.5880 - accuracy: 0.7875 - val_loss: 0.7870 - val_accuracy: 0.7456
# Epoch 21/30
# 113/113 [==============================] - 20s 171ms/step - loss: 0.4837 - accuracy: 0.8197 - val_loss: 0.7497 - val_accuracy: 0.7689
# Epoch 22/30
# 113/113 [==============================] - 21s 181ms/step - loss: 0.5146 - accuracy: 0.8128 - val_loss: 0.7566 - val_accuracy: 0.7733
# Epoch 23/30
# 113/113 [==============================] - 20s 169ms/step - loss: 0.4402 - accuracy: 0.8383 - val_loss: 0.6566 - val_accuracy: 0.8011
# Epoch 24/30
# 113/113 [==============================] - 22s 183ms/step - loss: 0.4203 - accuracy: 0.8450 - val_loss: 0.7090 - val_accuracy: 0.7811
# Epoch 25/30
# 113/113 [==============================] - 20s 173ms/step - loss: 0.3955 - accuracy: 0.8519 - val_loss: 0.6959 - val_accuracy: 0.7922
# Epoch 26/30
# 113/113 [==============================] - 22s 183ms/step - loss: 0.3676 - accuracy: 0.8614 - val_loss: 0.6866 - val_accuracy: 0.8156
# Epoch 27/30
# 113/113 [==============================] - 20s 172ms/step - loss: 0.3045 - accuracy: 0.8839 - val_loss: 0.7365 - val_accuracy: 0.8111
# Epoch 28/30
# 113/113 [==============================] - 21s 183ms/step - loss: 0.2989 - accuracy: 0.8925 - val_loss: 0.8905 - val_accuracy: 0.7389
# Epoch 29/30
#  28/113 [======>.......................] - ETA: 15s - loss: 0.2797 - accuracy: 0.8951

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **We can see by adding one more layer in the network we got an accurcy of 91% which is quite good**

# %%
# Verifying how the model is perfoming on the test datset
from tensorflow.keras.preprocessing.image import load_img
from glob import glob
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model_2.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[1] +'\n'+ "Predictive Class "+pred_class )

# %%
### We are able to identify 9 classes of skin cancer with an accuracy of 91%
